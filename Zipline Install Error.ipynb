# %%
import sys
print(sys.version)
# Out:
# 3.6.3 |Anaconda, Inc.| (default, Oct  6 2017, 12:04:38)
# [GCC 4.2.1 Compatible Clang 4.0.1 (tags/RELEASE_401/final)]

# %%
import sys
# !{sys.executable} -m pip install -r requirements.txt
# Out:
# ...
#   Using cached cvxpy-1.0.3.tar.gz (880 kB)
# ...
#   Using cached pandas-0.18.1.zip (8.5 MB)
# ...
#   Using cached plotly-2.2.3-py3-none-any.whl
# ...
#   Using cached pytz-2017.3-py2.py3-none-any.whl (511 kB)
# ...
#   Using cached tables-3.3.0-cp36-cp36m-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl (4.7 MB)
# ...
#   Using cached tqdm-4.19.5-py2.py3-none-any.whl (51 kB)
# ...
#   Using cached zipline-1.2.0-cp36-cp36m-macosx_10_7_x86_64.whl
# ...
#   Using cached bcolz-0.12.1.tar.gz (622 kB)
# ...
#   Using cached alembic-1.5.6-py2.py3-none-any.whl (159 kB)
# ...
#   Using cached cyordereddict-1.0.0-cp36-cp36m-macosx_10_7_x86_64.whl
# ...
#   Using cached pandas_datareader-0.5.0-py2.py3-none-any.whl (74 kB)
# ...
#   ERROR: Command errored out with exit status 1:
# ...

# %%
# !pip install zipline
# Out:
# ...
#   Using cached zipline-1.4.1-cp36-cp36m-macosx_10_7_x86_64.whl
# ...
#   Using cached alembic-1.5.6-py2.py3-none-any.whl (159 kB)
# ...
#   Using cached pytz-2021.1-py2.py3-none-any.whl (510 kB)
# ...
#   Using cached bcolz-1.2.1.tar.gz (1.5 MB)
# ...
#   ERROR: Command errored out with exit status 1:
#    command: /Users/vincentchong/opt/anaconda3/envs/py363/bin/python -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/1h/b7g52mjj3_v785kdd052yh9m0000gn/T/pip-install-clu54irb/bcolz_345425993f234b30be5d68daa7b5a2cd/setup.py'"'"'; __file__='"'"'/private/var/folders/1h/b7g52mjj3_v785kdd052yh9m0000gn/T/pip-install-clu54irb/bcolz_345425993f234b30be5d68daa7b5a2cd/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d /private/var/folders/1h/b7g52mjj3_v785kdd052yh9m0000gn/T/pip-wheel-qmhdygr4
# ...

# %%
from zipline.data import bundles
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-6d9190b35c40> in <module>()
# ----> 1 from zipline.data import bundles
#
# ModuleNotFoundError: No module named 'zipline'
